# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %matplotlib inline

t_data = pd.read_csv('transactions.csv', names=['tx_id','action','date','price','reward','balance'])

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="action", hue="reward", data=t_data)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="date", y='price', hue='action', style="reward", data=t_data[t_data['tx_id']==10626])
plt.show()

# %%
reward_df = t_data.groupby("tx_id").sum()[['reward']]
# reward_df[reward_df['reward']<-10]
reward_df.iloc[-30:]
# Out:
#        reward
# tx_id
# 10616   -2.20
# 10617    0.60
# 10618    1.00
# 10619    0.60
# 10620  -14.70
# 10621    0.35
# 10622    0.90
# 10623    0.65
# 10624   -4.80
# 10625    1.60
# 10626    3.30
# 10627    0.65
# 10628    1.05
# 10629    0.15
# 10630    1.05
# 10631    0.80
# 10632   -2.40
# 10633    1.60
# 10634    1.15
# 10635   -0.80
# 10636    0.95
# 10637    0.70
# 10638    0.20
# 10639    0.85
# 10640    0.80
# 10641    0.80
# 10642   -0.60
# 10643    0.25
# 10644  -13.70
# 10645   -9.00
